# %%
import numpy as np
import pickle

# %%
param_20000 = np.load("./saved_params_20000.npy")
param_20000
# Out:
# array([[ 0.67077687, -0.23089286,  0.2107714 , ..., -0.24325612,
#          0.30697651,  0.16935722],
#        [ 0.62002432, -0.15710839,  0.19309929, ..., -0.22979053,
#          0.41006636,  0.14109351],
#        [ 0.68149577, -0.23532929,  0.15657892, ..., -0.19713139,
#          0.29444426,  0.13894276],
#        ...,
#        [-0.24814962,  0.0569676 , -0.06212728, ...,  0.08740098,
#         -0.15010333, -0.05161992],
#        [-0.27383353,  0.06453744, -0.06993766, ...,  0.09958028,
#         -0.16578322, -0.06051012],
#        [-0.32114534,  0.07635757, -0.0862653 , ...,  0.11715802,
#         -0.19356651, -0.06976311]])

# %%
param_20000.shape
# Out:
# (39078, 10)

# %%
with open("./saved_state_20000.pickle", "rb") as file:
    state_20000 = pickle.load(file)

state_20000
# Out:
# (3,
#  (3033063947,
#   286456142,
#   2040275405,
#   1707019070,
#   389757557,
#   2554505244,
#   3426308112,
#   456672755,
#   1842403754,
#   3514460737,
#   3416078586,
#   711755237,
#   1933059060,
#   2086864708,
#   3624665389,
#   3868300052,
#   2475571212,
#   867751986,
#   1480762583,
#   1739223482,
#   421927069,
#   724332990,
#   2294928206,
#   3902631372,
#   432700361,
#   1429194480,
#   511021060,
#   1121262564,
#   36287215,
#   4259170953,
#   1712607659,
#   4064837884,
#   3494641332,
#   3302907053,
#   2868310947,
#   1171305053,
#   3411933320,
#   1981410903,
#   3829929747,
#   1447672678,
#   3764776779,
#   140301532,
#   2542824634,
#   3225090650,
#   2366250439,
#   191921412,
#   2814261482,
#   425387643,
#   3655434443,
#   2020506859,
#   2189743774,
#   1851118957,
#   1338614216,
#   4079234352,
#   796685204,
#   2593779004,
#   892292448,
#   3881717576,
#   3259801054,
#   3103203506,
#   711222017,
#   4144419611,
#   1031243284,
# ...
